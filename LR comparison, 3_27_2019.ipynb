# %%
import numpy as np
import scipy.linalg as la
from matplotlib import pyplot as plt
from scipy import sparse as sp
from time import time
import scipy.sparse.linalg as spla
from math import sqrt
import simulated_data as simd
import data_strm_subclass as dssb
import streaming_subclass as stsb
import plot_functions as pf

# %%
def expvar(X, W, Xnorm2=None):
    if Xnorm2 is None:
        Xnorm2 = la.norm(X, ord='fro')**2
    return la.norm(X @ W, ord='fro')**2 / Xnorm2

# %% [markdown]
# # Synthetic Data

# %%
n = 10000
B = 15
d = 1000
num_acc = 100

# %%
# Initialize learning rate comparison object for spiked covariance model
spcov_lr = pf.compare_lr(base=5., lower=-5., upper=10.)
for sigma in [.1, .25, .5, .75, 1, 1.5]:
    for k in [1, 5, 10]:
        cov, w, A0, X = simd.spiked_covariance(n, d, k, sigma=sigma)
        #V = la.eigh(np.cov(X.T))[1][:,::-1][:,:k]
        true_evar = expvar(X, A0)
        print(true_evar)
        '''
        Plot the true achievable explained variance?
        #v = la.eigh(np.cov(X.T))[1][:,::-1][:,:k]
        v = la.eigh(cov)[1][:,::-1][:,:k]
        c = 5.**np.arange(-5, 11)
        expvar = (la.norm(X @ v, ord='fro')**2) / (la.norm(X, ord='fro')**2)
        plt.plot(np.log(c), np.ones_like(c) * expvar, label='svd')
        '''
        spcov_lr.run_cval_fullX(X, k, B, Sparse=False)
        dataname = r'Spiked Covariance, $\sigma=$' + str(sigma) + ', k=' + str(k)
        spcov_lr.plot_cval_acc(dataname, 'spcov_sig' + str(sigma).replace(".","") + "_k" + str(k) + "cvals.png", true_evar=true_evar)
        spcov_lr.plot_bvals(dataname, "spcov_sig" + str(sigma).replace(".","") + "_k" + str(k) + "lr.png")
# Out:
# 0.092373144982
# 0.109290193205
# 0.313889036418
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-a82bf4536916> in <module>()
#      15         plt.plot(np.log(c), np.ones_like(c) * expvar, label='svd')
#      16         '''
# ---> 17         spcov_lr.run_cval_fullX(X, k, B, Sparse=False)
#      18         dataname = r'Spiked Covariance, $\sigma=$' + str(sigma) + ', k=' + str(k)
#      19         spcov_lr.plot_cval_acc(dataname, 'spcov_sig' + str(sigma).replace(".","") + "_k" + str(k) + "cvals.png", true_evar=true_evar)
#
# D:\Ward Research\Code\Proposal Code\plot_functions.py in run_cval_fullX(self, X, k, B, b0, m, Sparse, xnorm2)
#     153
#     154         # Initialize a list of oja objects
# --> 155         lin_list = [stsb.Oja(self.d, k, c=c, B=self.B, Sqrt=False, Sparse=Sparse, Acc=True, xnorm2=xnorm2, X=X, num_acc=1, Time=False, single_acc_B_index=self.test_index) for c in self.cvals]
#     156         sqrt_list = [stsb.Oja(self.d, k, c=c, B=B, Sqrt=True, Sparse=Sparse, Acc=True, xnorm2=xnorm2, X=X, num_acc=1, Time=False, single_acc_B_index=self.test_index) for c in self.cvals]
#     157         self.adaoja = stsb.AdaOja(self.d, k, b0=b0, B=B, Sparse=Sparse, Acc=True, xnorm2=xnorm2, X=X, num_acc=1, Time=False, single_acc_B_index=self.test_index)
#
# D:\Ward Research\Code\Proposal Code\plot_functions.py in <listcomp>(.0)
#     153
#     154         # Initialize a list of oja objects
# --> 155         lin_list = [stsb.Oja(self.d, k, c=c, B=self.B, Sqrt=False, Sparse=Sparse, Acc=True, xnorm2=xnorm2, X=X, num_acc=1, Time=False, single_acc_B_index=self.test_index) for c in self.cvals]
#     156         sqrt_list = [stsb.Oja(self.d, k, c=c, B=B, Sqrt=True, Sparse=Sparse, Acc=True, xnorm2=xnorm2, X=X, num_acc=1, Time=False, single_acc_B_index=self.test_index) for c in self.cvals]
#     157         self.adaoja = stsb.AdaOja(self.d, k, b0=b0, B=B, Sparse=Sparse, Acc=True, xnorm2=xnorm2, X=X, num_acc=1, Time=False, single_acc_B_index=self.test_index)
#
# D:\Ward Research\Code\Proposal Code\streaming_subclass.py in __init__(self, d, k, c, B, Sqrt, Sparse, Acc, X, xnorm2, num_acc, Time, single_acc_B_index)
#     310
#     311         '''
# --> 312         StreamingPCA.__init__(self, d, k, B=B, Sparse=Sparse, Acc=Acc, X=X, xnorm2=xnorm2, num_acc=num_acc, Time=Time)
#     313
#     314         if not float(single_acc_B_index).is_integer():
#
# D:\Ward Research\Code\Proposal Code\streaming_subclass.py in __init__(self, d, k, B, Sparse, Acc, X, xnorm2, num_acc, Time)
#     132         if self.Acc:
#     133             self.acc_init(X, num_acc)
# --> 134             self.xnorm2_init(xnorm2)
#     135
#     136                 # Initialize the components
#
# D:\Ward Research\Code\Proposal Code\streaming_subclass.py in xnorm2_init(self, xnorm2)
#     199                     self.xnorm2 = spla.norm(self.X, ord='fro')**2
#     200                 else:
# --> 201                     self.xnorm2 = la.norm(self.X, ord='fro')**2
#     202             # Take an initial reading of the explained variance
#     203             self.accQ.append(la.norm(self.X.dot(self.Q), ord='fro')**2 / self.xnorm2)
#
# C:\Program Files\Anaconda3\lib\site-packages\scipy\linalg\misc.py in norm(a, ord, axis, keepdims)
#     164             return np.linalg.norm(a, ord=ord, axis=axis, keepdims=keepdims)
#     165         return np.linalg.norm(a, ord=ord, axis=axis)
# --> 166     return np.linalg.norm(a, ord=ord)
#     167
#     168
#
# C:\Program Files\Anaconda3\lib\site-packages\numpy\linalg\linalg.py in norm(x, ord, axis, keepdims)
#    2165                 sqnorm = dot(x.real, x.real) + dot(x.imag, x.imag)
#    2166             else:
# -> 2167                 sqnorm = dot(x, x)
#    2168             ret = sqrt(sqnorm)
#    2169             if keepdims:
#
# KeyboardInterrupt:

# %%
# Initialize learning rate comparison object for spiked covariance model

for sigma in [.1, .25, .5, .75, 1, 1.5]:
    for k in [1, 5, 10]:
        cov, w, A0, X = simd.spiked_covariance(n, d, k, sigma=sigma)
        ada_cov, hpca_cov = dssb.run_sim_fullX(X, k, B=B, Sparse=False)
        '''
        # Plot svd vals?
        v = la.eigh(np.cov(X.T))[1][:,::-1][:,:k]
        c = 5.**np.arange(-5, 11)
        expvar = (la.norm(X @ v, ord='fro')**2) / (la.norm(X, ord='fro')**2)
        plt.plot(ada_cov.acc_indices, np.ones_like(ada_cov.acc_indices) * expvar, label='svd')
        '''
        plt.plot(ada_cov.acc_indices, ada_cov.accQ, '--', color='black', label='AdaOja')
        plt.plot(hpca_cov.acc_indices, hpca_cov.accQ, label='HPCA')
        plt.legend(loc='best')
        plt.title('HPCA vs AdaOja\n' + 'Spiked Covariance, k=' + str(k) + r', $\sigma=$' + str(sigma))
        plt.xlabel('Number of samples')
        plt.ylabel('Explained Variance')
        plt.savefig('hpcavada_' + 'spcov_k' + str(k) + 's'+ str(sigma).replace(".","") + '.png')
        plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-d3d6e518b400> in <module>()
#       3 for sigma in [.1, .25, .5, .75, 1, 1.5]:
#       4     for k in [1, 5, 10]:
# ----> 5         cov, w, A0, X = simd.spiked_covariance(n, d, k, sigma=sigma)
#       6         ada_cov, hpca_cov = dssb.run_sim_fullX(X, k, B=B, Sparse=False)
#       7         '''
#
# D:\Ward Research\Code\Proposal Code\simulated_data.py in spiked_covariance(n, d, k, sigma)
#      50
#      51     cov = A0 @ (w**2 * A0.T) + sigma**2 * np.eye(d)
# ---> 52     X = np.random.multivariate_normal(np.zeros(d), cov, size=n)
#      53     return cov, w, A0, X
#      54
#
# KeyboardInterrupt:

# %% [markdown]
# # Small Bag of Words Data

# %%
k = 10
B = 10

# %%
# Load Small bag of words data
kos_n, kos_d, kos_nnz, kos_dense, kos_SpX, kos_norm2 = dssb.get_bagX('docword.kos.txt') 
nips_n, nips_d, nips_nnz, nips_dense, nips_SpX, nips_norm2 = dssb.get_bagX('docword.nips.txt')
enr_n, enr_d, enr_nnz, enr_dense, enr_SpX, enr_norm2 = dssb.get_bagX('docword.enron.txt')

# %%
# Create learning rate comparison objects
kos_lr = pf.compare_lr()
nips_lr = pf.compare_lr()
enr_lr = pf.compare_lr()

# Run multiple c values for Oja vs AdaOja
kos_lr.run_cval_bag('docword.kos.txt', k, B=B, X=kos_SpX, xnorm2=kos_norm2)
nips_lr.run_cval_bag('docword.nips.txt', k, B=B, X=nips_SpX, xnorm2=nips_norm2)
enr_lr.run_cval_bag('docword.enron.txt', k, B=B, X=enr_SpX, xnorm2=enr_norm2)

# Plot the cval accuracies for each
kos_lr.plot_cval_acc('kos data', 'kos_cvals.png')
nips_lr.plot_cval_acc('nips data', 'nips_cvals.png')
enr_lr.plot_cval_acc('enr data', 'enr_cvals.png')

# Plot the best case learning rate comparisons for each
kos_lr.plot_bvals('kos data', 'kos_lr.png')
nips_lr.plot_bvals('nips data', 'nips_lr.png')
enr_lr.plot_bvals('enron data', 'enr_lr.png')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-57875653528a> in <module>()
#       6 # Run multiple c values for Oja vs AdaOja
#       7 kos_lr.run_cval_bag('docword.kos.txt', k, B=B, X=kos_SpX, xnorm2=kos_norm2)
# ----> 8 nips_lr.run_cval_bag('docword.nips.txt', k, B=B, X=nips_SpX, xnorm2=nips_norm2)
#       9 enr_lr.run_cval_bag('docword.enron.txt', k, B=B, X=enr_SpX, xnorm2=enr_norm2)
#      10
#
# D:\Ward Research\Code\Proposal Code\plot_functions.py in run_cval_bag(self, filename, k, B, b0, m, Sparse, X, xnorm2)
#      90                         oja_lin.add_block(Xi)
#      91                     for oja_sqrt in sqrt_list:
# ---> 92                         oja_sqrt.add_block(Xi)
#      93
#      94                     self.adaoja.add_block(Xi)
#
# D:\Ward Research\Code\Proposal Code\streaming_subclass.py in add_block(self, Xi, final_sample)
#     323
#     324     def add_block(self, Xi, final_sample=False):
# --> 325         StreamingPCA.add_block(self, Xi, final_sample=final_sample)
#     326         if self.Acc:
#     327             if self.block_num == self.single_acc_B_index and self.num_acc==1:
#
# D:\Ward Research\Code\Proposal Code\streaming_subclass.py in add_block(self, Xi, final_sample)
#     242         # Perform the update step for sparse or dense data, respectively
#     243         if self.Sparse:
# --> 244             self.sparse_update()
#     245         else:
#     246             self.dense_update()
#
# D:\Ward Research\Code\Proposal Code\streaming_subclass.py in sparse_update(self)
#     343
#     344         self.Q += eta * self.Xi.T.dot(self.Xi.dot(self.Q)) / self.B
# --> 345         self.Q = la.qr(self.Q, mode='economic')[0]
#     346
#     347 class AdaOja(StreamingPCA):
#
# C:\Program Files\Anaconda3\lib\site-packages\scipy\linalg\decomp_qr.py in qr(a, overwrite_a, lwork, mode, pivoting, check_finite)
#     163     elif mode == 'economic':
#     164         Q, = safecall(gor_un_gqr, "gorgqr/gungqr", qr, tau, lwork=lwork,
# --> 165             overwrite_a=1)
#     166     else:
#     167         t = qr.dtype.char
#
# C:\Program Files\Anaconda3\lib\site-packages\scipy\linalg\decomp_qr.py in safecall(f, name, *args, **kwargs)
#      19         ret = f(*args, **kwargs)
#      20         kwargs['lwork'] = ret[-2][0].real.astype(numpy.int)
# ---> 21     ret = f(*args, **kwargs)
#      22     if ret[-1] < 0:
#      23         raise ValueError("illegal value in %d-th argument of internal %s"
#
# KeyboardInterrupt:

# %%
def plot_hpca_ada(adaoja, hpca, data_name, k):
    plt.plot(adaoja.acc_indices, adaoja.accQ, '--', color='black', label='AdaOja')
    plt.plot(hpca.acc_indices, hpca.accQ, label='HPCA')
    plt.legend(loc='best')
    plt.title('HPCA vs AdaOja\n' + data_name + ' data set, k=' + str(k))
    plt.xlabel('Number of samples')
    plt.ylabel('Explained Variance')
    plt.savefig('hpcavada_' + data_name + '_k' + str(k) + '.png')
    plt.show()

# %%
# Plot HPCA convergence vs. AdaOja Convergence
adaoja_kos, hpca_kos = dssb.run_sim_bag('docword.kos.txt', k, B=B, X=kos_SpX, xnorm2=kos_norm2)
adaoja_nips, hpca_nips = dssb.run_sim_bag('docword.nips.txt', k, B=B, X=nips_SpX, xnorm2=nips_norm2)
adaoja_enr, hpca_enr = dssb.run_sim_bag('docword.enron.txt', k, B=B, X=enr_SpX, xnorm2=enr_norm2)

# %%
plot_hpca_ada(adaoja_kos, hpca_kos, 'Kos', k)
plot_hpca_ada(adaoja_nips, hpca_nips, 'Nips', k)
plot_hpca_ada(adaoja_enr, hpca_enr, 'Enron', k)

# %% [markdown]
# # Large Bag of Words Data

# %%
B = 100
k = 10
nyt_n, nyt_d, nyt_nnz, nyt_dense, nyt_SpX, nyt_norm2 = dssb.get_bagXblocks('docword.nytimes.txt', B)
pm_n, pm_d, pm_nnz, pm_dense, pm_SpX, pm_norm2 = dssb.get_bagXblocks('docword.pubmed.txt', B, block_total=3000)

# %%
nyt_lr = pf.compare_lr()
nyt_lr.run_cval_blocklist(nyt_SpX, k, xnorm2=nyt_norm2)
nyt_lr.plot_cval_acc('Nytimes data', 'nyt_cvals.png')
nyt_lr.plot_bvals('Nytimes data', 'nyt_lr.png')

# %%
pm_lr = pf.compare_lr(base=2., lower=-5, upper=15)
pm_lr.run_cval_blocklist(pm_SpX, k, xnorm2=pm_norm2)
pm_lr.plot_cval_acc('Pubmed data', 'pm_cvals.png')
pm_lr.plot_bvals('Pubmed data', 'pm_lr.png')

# %%
adaoja_nyt, hpca_nyt = dssb.run_sim_blocklist(nyt_SpX, k, xnorm2=nyt_norm2)
adaoja_pm, hpca_pm = dssb.run_sim_blocklist(pm_SpX, k, xnorm2=pm_norm2)

# %%
plot_hpca_ada(adaoja_nyt, hpca_nyt, 'Nytimes', k)
plot_hpca_ada(adaoja_pm, hpca_pm, 'Pubmed', k)
